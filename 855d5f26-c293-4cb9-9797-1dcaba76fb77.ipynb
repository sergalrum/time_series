# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Библиотеки" data-toc-modified-id="Библиотеки-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Библиотеки</a></span></li><li><span><a href="#Откроем-и-изучим-файлы" data-toc-modified-id="Откроем-и-изучим-файлы-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Откроем и изучим файлы</a></span><ul class="toc-item"><li><span><a href="#Общая-информация" data-toc-modified-id="Общая-информация-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Общая информация</a></span></li></ul></li><li><span><a href="#Вывод-по-итогу-изучения-данных" data-toc-modified-id="Вывод-по-итогу-изучения-данных-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Вывод по итогу изучения данных</a></span></li><li><span><a href="#Ресемплирование" data-toc-modified-id="Ресемплирование-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Ресемплирование</a></span></li></ul></li><li><span><a href="#Анализ" data-toc-modified-id="Анализ-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ</a></span><ul class="toc-item"><li><span><a href="#Скользящее-среднее" data-toc-modified-id="Скользящее-среднее-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Скользящее среднее</a></span></li><li><span><a href="#Составляющие-временного-ряда" data-toc-modified-id="Составляющие-временного-ряда-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Составляющие временного ряда</a></span></li><li><span><a href="#Вывод-по-итогу-анализа-данных" data-toc-modified-id="Вывод-по-итогу-анализа-данных-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Вывод по итогу анализа данных</a></span></li></ul></li><li><span><a href="#Обучение" data-toc-modified-id="Обучение-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Обучение</a></span><ul class="toc-item"><li><span><a href="#Создание-признаков" data-toc-modified-id="Создание-признаков-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Создание признаков</a></span></li><li><span><a href="#Разбиение-финальных-данных-на-выборки" data-toc-modified-id="Разбиение-финальных-данных-на-выборки-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Разбиение финальных данных на выборки</a></span><ul class="toc-item"><li><span><a href="#Масштабирование-данных" data-toc-modified-id="Масштабирование-данных-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Масштабирование данных</a></span></li></ul></li><li><span><a href="#Линейная-регрессия" data-toc-modified-id="Линейная-регрессия-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Линейная регрессия</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Случайный лес</a></span></li><li><span><a href="#LightGBM" data-toc-modified-id="LightGBM-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>LightGBM</a></span></li><li><span><a href="#CatBoost" data-toc-modified-id="CatBoost-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>CatBoost</a></span></li><li><span><a href="#Анализ-моделей" data-toc-modified-id="Анализ-моделей-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Анализ моделей</a></span></li></ul></li><li><span><a href="#Тестирование" data-toc-modified-id="Тестирование-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Тестирование</a></span><ul class="toc-item"><li><span><a href="#Проверка-модели-на-адекватность" data-toc-modified-id="Проверка-модели-на-адекватность-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Проверка модели на адекватность</a></span></li></ul></li><li><span><a href="#Чек-лист-проверки" data-toc-modified-id="Чек-лист-проверки-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Чек-лист проверки</a></span></li></ul></div>

# %% [markdown]
# #  Прогнозирование заказов такси

# %% [markdown]
# Компания «Чётенькое такси» собрала исторические данные о заказах такси в аэропортах. Чтобы привлекать больше водителей в период пиковой нагрузки, нужно спрогнозировать количество заказов такси на следующий час. Постройте модель для такого предсказания.
#
# Значение метрики *RMSE* на тестовой выборке должно быть не больше 48.
#
# Вам нужно:
#
# 1. Загрузить данные и выполнить их ресемплирование по одному часу.
# 2. Проанализировать данные.
# 3. Обучить разные модели с различными гиперпараметрами. Сделать тестовую выборку размером 10% от исходных данных.
# 4. Проверить данные на тестовой выборке и сделать выводы.
#
#
# Данные лежат в файле `taxi.csv`. Количество заказов находится в столбце `num_orders` (от англ. *number of orders*, «число заказов»).

# %% [markdown]
# # Критерии, которые важны заказчику:
#
# - качество предсказания (RMSE на тестовой выборке должно быть не больше 48);
# - время обучения модели и время предсказания модели вторичны.

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Библиотеки

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats as st

# %%
# %%capture

# !pip install ydata-profiling
# from ydata_profiling import ProfileReport

# !pip install dtale
# import dtale

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
# функции предобработки
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
# from sklearn.utils import shuffle
# from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder

# функции машинного обучения
from sklearn.linear_model import LinearRegression
# from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import mean_absolute_error, make_scorer, mean_squared_error as mse
from sklearn.model_selection import cross_val_score, TimeSeriesSplit

# from sklearn.metrics import f1_score, roc_auc_score, confusion_matrix
from sklearn.dummy import DummyRegressor, DummyClassifier

# %%
# %%capture

# !pip install category_encoders
# import category_encoders as ce

# !pip install catboost
from catboost import CatBoostRegressor

# !pip install lightgbm
import lightgbm as lgb
from lightgbm import LGBMRegressor

# %% [markdown]
# ### Откроем и изучим файлы

# %% [markdown]
# #### Общая информация

# %%
try:
    df = pd.read_csv('/datasets/taxi.csv', index_col=[0], parse_dates=[0])
except:
    df = pd.read_csv('taxi.csv', index_col=[0], parse_dates=[0])

# %%
df.sort_index(inplace=True)

# %%
# не сочетаются с matplotlib, сбивают его настройки

# dtale.show(df)
# ProfileReport(df)

# %%
df.head()
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00           9
# 2018-03-01 00:10:00          14
# 2018-03-01 00:20:00          28
# 2018-03-01 00:30:00          20
# 2018-03-01 00:40:00          32

# %%
df.describe()
# Out:
#          num_orders
# count  26496.000000
# mean      14.070463
# std        9.211330
# min        0.000000
# 25%        8.000000
# 50%       13.000000
# 75%       19.000000
# max      119.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 26496 entries, 2018-03-01 00:00:00 to 2018-08-31 23:50:00
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  26496 non-null  int64
# dtypes: int64(1)
# memory usage: 414.0 KB

# %%
round(df.isna().sum() / len(df) * 100, 2)
# Out:
# num_orders    0.0
# dtype: float64

# %%
# Проверим явные дубликаты по времени
df.index.duplicated().sum()
# Out:
# 0

# %%
df.hist(bins=30)
plt.show()

# %%
df.loc[df.num_orders == 119].count()
# Out:
# num_orders    2
# dtype: int64

# %% [markdown]
# ### Вывод по итогу изучения данных
#
#
#
# `2018-03-01 00:00:00` - дата начала измерения
# `2018-08-31 23:50:00` - дата окончания измерения
#
# При необходимости можно ограничить выбивающиеся значения, однако такое количество (119) присутствует более одного раза за пол года.
#
# ---
#
# - Пропуски отсутствуют
# - Дубликаты по времени отсутствуют
# - Неинформативные столбцы отсутствуют
#  - Выбивающиеся значения удалять не будем

# %% [markdown]
# ### Ресемплирование

# %%
df_clear = df.resample('1H').sum()

# %% [markdown]
# ## Анализ

# %%
df_clear.plot()

plt.title('График распределения заказов такси по часам')
plt.ylabel('Количество')
plt.xlabel('Дата')
plt.show()

# %% [markdown]
# ### Скользящее среднее

# %% [markdown]
# Добавим столбец 'rolling_mean' - скользящее среднее с размером окна, равным 120 (эквивалент 5 дней)

# %%
def inscription(title, yl, xl):
    plt.title(title)
    plt.ylabel(yl)
    plt.xlabel(xl)
    plt.show()

# %%
df_clear['rolling_mean'] = df_clear.rolling(120).mean()
# df_clear['rolling_mean'] = df_clear['num_orders'].shift().rolling(120).mean()

df_clear.plot(figsize=(15, 7))

inscription('График среднего распределения заказов такси по часам', 'Количество', 'Дата, время')
df_clear = df_clear.drop('rolling_mean', axis=1) # для отладки

# %% [markdown]
# ### Составляющие временного ряда

# %%
decomposed = seasonal_decompose(df_clear.num_orders)

plt.figure(figsize=(6, 8))
plt.subplot(311)

decomposed.trend.plot(ax=plt.gca(), figsize=(10, 10))
plt.title('Trend')
plt.subplot(312)

decomposed.seasonal['2018-03-01':'2018-03-05'].plot(ax=plt.gca(), figsize=(10, 10))
plt.title('Seasonality')
plt.subplot(313)

decomposed.resid.plot(ax=plt.gca(), figsize=(10, 10))
plt.title('Residuals')
plt.tight_layout()

# %% [markdown]
# ### Вывод по итогу анализа данных
#
# Поскольку данные ограничены шестью месяцами, годовой цикл сезонности выявить не получится (можно предположить, что август является пиковым значением, ввиду дальнейшего снижения турристического потенциала аэропорта)
#
# - Тренд связан с временем года: летом количество пользователей такси у аэропорта выше. Значение растет в течении наблюдаемого периода.
# - Cезонность с периодом меньше месяца — дневная. Пик заказов в 00:00, а наименьшее число в 06:00.
# - Остатки необъяснимы.
#
# ---
#
# Ключевые данные:
#
# Следующие календарные признаки будем закладывать в модель:
# - Месяц и число (по графику тренда)
# - Часы (по графику сезонности)
# - День недели (по графику остатков)

# %% [markdown]
# ## Обучение

# %% [markdown]
# *Переборы урезаны в целях экономии времени после подбора гиперпараметров*

# %%
# Функция для подсчета RMSE
def rmse(target, predicted):
    return mse(target, predicted) ** 0.5

# %% [markdown]
# Обучим разные модели. Для каждой модели попробуем разные гиперпараметры.
#
# Воспользуемся следующими моделями:
# - Линейная регрессия;
# - Случайный лес;
# - CatBoost;
# - LightGBM;

# %% [markdown]
# Создадим вспомогательный класс для фиксации результатов моделей

# %%
import time

class Helper:
    def __init__(self, name, model): # инициализация модели
        self.name = name
        self.model = model
        
    def fit(self, feature, target): # обучение
        start = time.time()
        self.model.fit(feature, target)
        end = time.time()
        self.fit_time = end - start
        
    def predict(self, feature, target): # предсказание
        start = time.time()
        predicted = self.model.predict(feature)
        end = time.time()
        self.predicted_time = end - start
        self.rmse = round(rmse(target, predicted), 2)
        
    def getResult(self): # фиксация результатов модели
        return self.name, self.fit_time, self.predicted_time, self.rmse

# %%
result = []

# %% [markdown]
# ### Создание признаков

# %%
def make_features(data, max_lag, rolling_mean_size):
#     data['year'] = data.index.year
#     data['month'] = data.index.month
    data['day'] = data.index.day
    data['dayofweek'] = data.index.dayofweek
    data['hour'] = data.index.hour
    
    for lag in range(1, max_lag + 1):
        data['lag_{}'.format(lag)] = data['num_orders'].shift(lag)

    data['rolling_mean'] = data['num_orders'].shift().rolling(rolling_mean_size).mean()

# %% [markdown]
# Перебором на линейной регрессии подберем параметры функции make_features

# %%
# Код
from statsmodels.graphics import tsaplots

taxi = df.copy().resample('1H').sum()
ts = taxi['num_orders']

fig = tsaplots.plot_acf(ts,lags= 190)
fig.set_size_inches(18.5, 6)
plt.ylim(-.1, 1.1)
plt.show()

# %%
# %%time

# resut_make_features = []

# for lag in range(24, 96, 24):
#     df_lr = df_clear.copy()
#     make_features(df_lr, lag, 24)
    
#     # отделим 10% для тестовой и валидационной выборок
#     train_valid, test = train_test_split(df_lr, shuffle=False, test_size=0.1)
#     train, valid = train_test_split(train_valid, shuffle=False, test_size=0.1)
#     train = train.dropna()
    
    
#     target_train = train['num_orders']
#     features_train = train.drop(['num_orders'] , axis=1)
#     target_valid = valid['num_orders']
#     features_valid = valid.drop(['num_orders'] , axis=1)
    
#     model = LinearRegression()
    
#     model.fit(features_train, target_train)
#     predicted_train = model.predict(features_train)
#     predicted_valid = model.predict(features_valid)
     
#     rmse_train = rmse(target_train, predicted_train)
#     rmse_valid = rmse(target_valid, predicted_valid)
    
#     resut_make_features.append([lag, 24, rmse_train, rmse_valid])

# %%
# resut_make_features = pd.DataFrame(resut_make_features, columns=['lag_features', 'rolling_mean',
#                                  'RMSE обучающей выборки', 'RMSE валидационной выборки']).head(20)

# %%
# best_resut_make_features = resut_make_features.sort_values(by=['RMSE обучающей выборки']).head(5)
# best_resut_make_features

# %% [markdown]
# ###### Вывод по итогу подбора параметров функции make_features
#
# Наблюдаем более сильную корреляюцию на 48 и 168 лагах, используем их в качестве параметров

# %%
LAG_FEATURES = 48
ROLLING_MEAN = 168

make_features(df_clear, LAG_FEATURES, ROLLING_MEAN)

# %% [markdown]
# ### Разбиение финальных данных на выборки

# %%
RANDOM_STATE = 42

# %%
# отделим 10% для тестовой
train, test = train_test_split(df_clear, shuffle=False, test_size=0.1)

# отделим 10% для валидационной
# train, valid = train_test_split(tv, shuffle=False, test_size=0.1)

train = train.dropna()
# tv = tv.dropna()

# %%
features_train = train.drop(['num_orders'] , axis=1)
# features_tv = tv.drop(['num_orders'] , axis=1)
# features_valid = valid.drop(['num_orders'] , axis=1)
features_test = test.drop(['num_orders'] , axis=1)

target_train = train['num_orders']
# target_tv = tv['num_orders']
# target_valid = valid['num_orders']
target_test = test['num_orders']

# %% [markdown]
# #### Масштабирование данных

# %%
# Удаление предупреждения
# pd.options.mode.chained_assignment = None

# %%
# %%time

# # Создадим объект структуры и настроим его на обучающих данных
# scaler = StandardScaler()
# scaler.fit(features_train[list(features_train.columns)])

# features_train[list(features_train.columns)] = scaler.transform(features_train[list(features_train.columns)])
# # features_tv[list(features_tv.columns)] = scaler.transform(features_tv[list(features_tv.columns)])
# features_valid[list(features_valid.columns)] = scaler.transform(features_valid[list(features_valid.columns)])
# features_test[list(features_test.columns)] = scaler.transform(features_test[list(features_test.columns)])

# %% [markdown]
# ### Линейная регрессия

# %%
model_lr = LinearRegression()
model_lr_helper = Helper('Linear regression', model_lr)
model_lr_helper.fit(features_train, target_train)

# %%
# model_lr_helper.predict(features_valid, target_valid)
model_lr_helper.predict(features_train, target_train)
result.append(model_lr_helper.getResult())

# %% [markdown]
# ### Случайный лес

# %%
# tscv = TimeSeriesSplit(n_splits=5)

# %%
# %%time

# Перебор случайного леса *урезан в целях экономии времени после подбора гиперпараметров*
parameters = {'n_estimators': range(250, 251, 50),'max_depth': range(33, 34, 3),
              'min_samples_leaf': range(4, 5, 2), 'min_samples_split': range(2, 3, 2)}

model = RandomForestRegressor()
grid = GridSearchCV(model, parameters, cv=TimeSeriesSplit(n_splits=5), scoring='neg_root_mean_squared_error')
grid.fit(features_train, target_train)

grid.best_params_


# Получим следующие результаты:

# {'max_depth': 30,
#  'min_samples_leaf': 4,
#  'min_samples_split': 2,
#  'n_estimators': 250}
# Out:
# CPU times: total: 1min 21s
# Wall time: 1min 21s
# {'max_depth': 33,
#  'min_samples_leaf': 4,
#  'min_samples_split': 2,
#  'n_estimators': 250}

# %%
# # Для ручной отладки
# DEPTH = 33
# SAMPLES_LEAF = 4
# SAMPLES_SPLIT = 2
# N_ESTINATORS = 250

# model_rfr = RandomForestRegressor(max_depth=DEPTH, min_samples_leaf=SAMPLES_LEAF,
#                                   min_samples_split=SAMPLES_SPLIT, n_estimators=N_ESTINATORS,
#                                   random_state=RANDOM_STATE)

# %%
# %%time

model_rfr = grid.best_estimator_ # Для автоматической отладки
model_rfr_helper = Helper('Random Forest', model_rfr)
model_rfr_helper.fit(features_train, target_train)
# Out:
# CPU times: total: 24.2 s
# Wall time: 24.2 s

# %%
# model_rfr_helper.predict(features_valid, target_valid)
model_rfr_helper.predict(features_train, target_train)
result.append(model_rfr_helper.getResult())

# %% [markdown]
# ### LightGBM

# %%
# %%time

gbm = LGBMRegressor(boosting_type='gbdt', verbose=0, seed=RANDOM_STATE, force_row_wise='true')
gbm_params = {'learning_rate': np.arange(0.05, 0.1, 0.1),
              'n_estimators': range(60, 62, 5),
              'num_leaves': range(30, 31, 5)}

grid_gbm = GridSearchCV(gbm, gbm_params, cv=TimeSeriesSplit(n_splits=5), scoring='neg_root_mean_squared_error')

grid_gbm.fit(features_train, target_train);

grid_gbm.best_params_

# {'learning_rate': 0.05, 'n_estimators': 60, 'num_leaves': 30}
# Out:
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
model_gbm = grid_gbm.best_estimator_
model_gbm_helper = Helper('LightGBM', model_gbm)
model_gbm_helper.fit(features_train, target_train)

# %%
# model_gbm_helper.predict(features_valid, target_valid)
model_gbm_helper.predict(features_train, target_train)
result.append(model_gbm_helper.getResult())

# %% [markdown]
# ### CatBoost

# %%
# CatBoost совсем грустный получается

# %%
# 'learning_rate': np.arange(0.05, 0.31, 0.1),

# %%
# %%time

# cbr = CatBoostRegressor(loss_function='RMSE', silent=True, random_seed=RANDOM_STATE)
# cbr_params = {'iterations': range(50, 61, 10),
#               'depth': range(2, 7, 2),
#              'learning_rate': np.arange(0.05, 0.31, 0.1),}

# grid_cbr = GridSearchCV(cbr, cbr_params, cv=3, scoring='neg_mean_squared_error')
# grid_cbr.fit(features_train, target_train);

# grid_cbr.best_params_

# # {'depth': 4, 'iterations': 60}

# %%
# model_cbr = grid_cbr.best_estimator_
# model_cbr_helper = Helper('CatBoost', model_cbr)
# model_cbr_helper.fit(features_train, target_train)

# %%
# model_cbr_helper.predict(features_valid, target_valid)
# result.append(model_cbr_helper.getResult())

# %% [markdown]
# ### Анализ моделей

# %%
result_no_scaler = pd.DataFrame(result,
                                columns=['Модель', 'Время обучения', 'Время предсказания', 'RMSE тренировочной выбори'])
result_no_scaler
# Out:
#               Модель  Время обучения  Время предсказания  \
# 0  Linear regression        0.002646            0.000000
# 1      Random Forest       24.206595            0.103882
# 2           LightGBM        0.148433            0.000000
#
#    RMSE тренировочной выбори
# 0                      23.46
# 1                      11.97
# 2                      17.60

# %% [markdown]
# <!-- Ниже значения c прямым перебором параметров для создания признаков (для сравнения) -->

# %% [markdown]
# |Значения c прямым перебором параметров для создания признаков (для сравнения)|
# :----:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Исходя из требований RMSE следует отдать предпочтение **Линейной регрессии**
#
# Также модель обладает отличной скоростью обучения и предсказания

# %% [markdown]
# ## Тестирование

# %%
test_result = []

model_lr_helper.predict(features_test, target_test)
test_result.append(model_lr_helper.getResult())

model_rfr_helper.predict(features_test, target_test)
test_result.append(model_rfr_helper.getResult())

model_gbm_helper.predict(features_test, target_test)
test_result.append(model_gbm_helper.getResult())

# # model_cbr_helper.predict(features_test, target_test)
# # test_result.append(model_cbr_helper.getResult())

pd.DataFrame(test_result, columns=['Модель', 'Время обучения', 'Время предсказания', 'RMSE на тестовой выборке'])
# Out:
#               Модель  Время обучения  Время предсказания  \
# 0  Linear regression        0.002646            0.001999
# 1      Random Forest       24.206595            0.028730
# 2           LightGBM        0.148433            0.000000
#
#    RMSE на тестовой выборке
# 0                     41.59
# 1                     40.00
# 2                     41.65

# %% [markdown]
# Смотреть на время обучения LightGBM
#
# ![image.png](attachment:image.png)

# %%
lr_predictions = model_lr.predict(features_test)

# %%
prediction_list = [model_lr.predict(features_test), model_rfr.predict(features_test), model_gbm.predict(features_test)]
model_list = ['LinearRegression','RandomForestRegressor','LGBMRegressor']
for pred in range(len(prediction_list)):
    plt.figure(figsize=(10, 4)) 
    plt.scatter(y=target_test, x=target_test.index, label='Real data')
    plt.scatter(y=prediction_list[pred], x=target_test.index, label='Predictions')
    plt.legend(loc='upper right')
    plt.title(model_list[pred])
    plt.show()

# %% [markdown]
# ### Проверка модели на адекватность

# %%
dummy_regr = DummyRegressor(strategy="mean")
dummy_regr.fit(features_train, target_train)

mean_predictions = dummy_regr.predict(features_test)
mean_rmse = rmse(target_test, mean_predictions)

# %%
print('RMSE модели на выборке средних значений составляет:', mean_rmse)
# Out:
# RMSE модели на выборке средних значений составляет: 83.97941361168559

# %% [markdown]
# # Итоговый вывод
#
# Проведёно:
#
# - анализ данных без выяления особых проблем
# - подготовка данных для исследования и обучения модели
# - исследование имеющихся данных
# - выбор лучшей модели из разобранных
# - тестирование модели
#
# Исходя из проработанного материала выберем модель **Линейной регрессии**

# %% [markdown]
# ## Чек-лист проверки

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [ ]  Весь код выполняется без ошибок
# - [ ]  Ячейки с кодом расположены в порядке исполнения
# - [ ]  Данные загружены и подготовлены
# - [ ]  Данные проанализированы
# - [ ]  Модель обучена, гиперпараметры подобраны
# - [ ]  Качество моделей проверено, выводы сделаны
# - [ ]  Значение *RMSE* на тестовой выборке не больше 48
